# %% [markdown]
# ### Import Modules

# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier, XGBRFClassifier
from sklearn.model_selection import cross_val_score

import sys
sys.path.append("../")

from scripts.modeling_utils import run_train_pipeline, get_pipeline, dvc_get_data

import os
import mlflow

# %% [markdown]
# ### Modeling for Versioned Data Based on Browser

# %% [markdown]
# ### Chrome Mobile (v3 on dvc)

# %%
df = dvc_get_data(path='data/AdSmartABdata.csv', 
                version='v3', experiment_name="Chrome Mobile")
df = df.drop(columns=['Unnamed: 0'])
df.info()
# Out:
# 2022/09/01 09:50:30 INFO mlflow.tracking.fluent: Experiment with name 'Chrome Mobile' does not exist. Creating a new experiment.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 695 entries, 0 to 694
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   experiment   695 non-null    object
#  1   hour         695 non-null    int64
#  2   platform_os  695 non-null    int64
#  3   browser      695 non-null    object
#  4   day_of_week  695 non-null    object
#  5   brand        695 non-null    object
#  6   response     695 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 38.1+ KB

# %% [markdown]
# #### Logistic Regression on Browser Chrome Mobile

# %%
try:
    mlflow.end_run()
except:
    pass

# %%
X = df.drop(columns=['response'])
y = df['response'].values
model = LogisticRegression()
run_train_pipeline(model, X, y, 
                experiment_name='Chrome Mobile Browser',
                run_name='Logistic regression')

mlflow.end_run()
# Out:
# {'accuracy': 0.52, 'precision': 0.41, 'recall': 0.21, 'entropy': 0.7, 'true_pos': 90, 'true_neg': 19, 'false_pos': 27, 'false_neg': 73}
# {'experiment': -0.12, 'hour': 0.08, 'platform_os': 0.0, 'browser': 0.0, 'day_of_week': 0.14, 'brand': 0.21}
# 2022/09/01 09:50:33 INFO mlflow.tracking.fluent: Experiment with name 'Chrome Mobile Browser' does not exist. Creating a new experiment.
# Run params saved
# Run metrics saved
# logging figures
# figures saved with mlflow
# figures saved
# Saving artifacts
# saving dict
# /home/n/anaconda3/lib/python3.9/site-packages/_distutils_hack/__init__.py:30: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# Successfully registered model 'Chrome Mobile Browser_Logistic regression_Thu-Sep--1-09:50:46-2022'.
# ...

# %% [markdown]
# #### RandomForestClassifier on Browser Chrome Mobile

# %%
model = RandomForestClassifier(max_depth=20)
run_train_pipeline(model, X, y, 
                experiment_name='Chrome Mobile Browser',
                run_name='depth 20 random forest')
mlflow.end_run()
# Out:
# {'accuracy': 0.52, 'precision': 0.44, 'recall': 0.33, 'entropy': 0.91, 'true_pos': 79, 'true_neg': 30, 'false_pos': 38, 'false_neg': 62}
# {'experiment': 0.04, 'hour': 0.72, 'platform_os': 0.0, 'browser': 0.0, 'day_of_week': 0.21, 'brand': 0.03}
# Run params saved
# Run metrics saved
# logging figures
# figures saved with mlflow
# figures saved
# Saving artifacts
# saving dict
# Successfully registered model 'Chrome Mobile Browser_depth 20 random forest_Thu-Sep--1-09:51:10-2022'.
# 2022/09/01 09:51:18 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: Chrome Mobile Browser_depth 20 random forest_Thu-Sep--1-09:51:10-2022, version 1
# Created version '1' of model 'Chrome Mobile Browser_depth 20 random forest_Thu-Sep--1-09:51:10-2022'.
# Run - depth 20 random forest is logged to Experiment - Chrome Mobile Browser

# %% [markdown]
# #### XGBoost on Browser Chrome Mobile

# %%
model = XGBClassifier()
run_train_pipeline(model, X, y, 
                experiment_name='Chrome Mobile Browser',
                run_name='XGBoost Classifier')
mlflow.end_run()
# Out:
# {'accuracy': 0.51, 'precision': 0.43, 'recall': 0.34, 'entropy': 0.85, 'true_pos': 76, 'true_neg': 31, 'false_pos': 41, 'false_neg': 61}
# {'experiment': 0.25, 'hour': 0.28, 'platform_os': 0.0, 'browser': 0.0, 'day_of_week': 0.24, 'brand': 0.22}
# Run params saved
# Run metrics saved
# logging figures
# figures saved with mlflow
# figures saved
# Saving artifacts
# saving dict
# Successfully registered model 'Chrome Mobile Browser_XGBoost Classifier_Thu-Sep--1-09:51:35-2022'.
# 2022/09/01 09:51:49 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: Chrome Mobile Browser_XGBoost Classifier_Thu-Sep--1-09:51:35-2022, version 1
# Created version '1' of model 'Chrome Mobile Browser_XGBoost Classifier_Thu-Sep--1-09:51:35-2022'.
# Run - XGBoost Classifier is logged to Experiment - Chrome Mobile Browser

# %% [markdown]
# ### Chrome Mobile WebView (v4 on dvc)

# %%
df = dvc_get_data(path='data/AdSmartABdata.csv', 
                version='v4', experiment_name="Chrome Mobile Webview Browser")
df = df.drop(columns=['Unnamed: 0'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   experiment   227 non-null    object
#  1   hour         227 non-null    int64
#  2   platform_os  227 non-null    int64
#  3   browser      227 non-null    object
#  4   day_of_week  227 non-null    object
#  5   brand        227 non-null    object
#  6   response     227 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 12.5+ KB

# %% [markdown]
# #### Logistic Regression on Browser Chrome Mobile  Webview

# %%
try:
    mlflow.end_run()
except:
    pass

# %%
X = df.drop(columns=['response'])
y = df['response'].values
model = LogisticRegression()
run_train_pipeline(model, X, y, 
                experiment_name='Chrome Mobile Webview Browser',
                run_name='Logistic regression')

mlflow.end_run()
# Out:
# {'accuracy': 0.61, 'precision': 0.6, 'recall': 0.72, 'entropy': 0.67, 'true_pos': 16, 'true_neg': 26, 'false_pos': 17, 'false_neg': 10}
# {'experiment': 0.19, 'hour': 0.27, 'platform_os': 0.0, 'browser': 0.0, 'day_of_week': -0.07, 'brand': 0.16}
# Run params saved
# Run metrics saved
# logging figures
# figures saved with mlflow
# figures saved
# Saving artifacts
# saving dict
# Successfully registered model 'Chrome Mobile Webview Browser_Logistic regression_Thu-Sep--1-09:54:36-2022'.
# 2022/09/01 09:54:46 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: Chrome Mobile Webview Browser_Logistic regression_Thu-Sep--1-09:54:36-2022, version 1
# Created version '1' of model 'Chrome Mobile Webview Browser_Logistic regression_Thu-Sep--1-09:54:36-2022'.
# Run - Logistic regression is logged to Experiment - Chrome Mobile Webview Browser

# %% [markdown]
# #### RandomForestClassifier on Browser Chrome Mobile WebView

# %%
model = RandomForestClassifier(max_depth=20)
run_train_pipeline(model, X, y, 
                experiment_name='Chrome Mobile WebView Browser',
                run_name='depth 20 random forest')
mlflow.end_run()
# Out:
# {'accuracy': 0.51, 'precision': 0.52, 'recall': 0.58, 'entropy': 0.94, 'true_pos': 14, 'true_neg': 21, 'false_pos': 19, 'false_neg': 15}
# {'experiment': 0.05, 'hour': 0.6, 'platform_os': 0.0, 'browser': 0.0, 'day_of_week': 0.29, 'brand': 0.06}
# 2022/09/01 09:55:44 INFO mlflow.tracking.fluent: Experiment with name 'Chrome Mobile WebView Browser' does not exist. Creating a new experiment.
# Run params saved
# Run metrics saved
# logging figures
# figures saved with mlflow
# figures saved
# Saving artifacts
# saving dict
# Successfully registered model 'Chrome Mobile WebView Browser_depth 20 random forest_Thu-Sep--1-09:55:53-2022'.
# 2022/09/01 09:56:00 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: Chrome Mobile WebView Browser_depth 20 random forest_Thu-Sep--1-09:55:53-2022, version 1
# ...

# %% [markdown]
# #### XGBoost on Browser Chrome Mobile WebView

# %%
model = XGBClassifier()
run_train_pipeline(model, X, y, 
                experiment_name='Chrome Mobile WebView Browser',
                run_name='XGBoost Classifier')
mlflow.end_run()
# Out:
# {'accuracy': 0.46, 'precision': 0.49, 'recall': 0.47, 'entropy': 1.18, 'true_pos': 15, 'true_neg': 17, 'false_pos': 18, 'false_neg': 19}
# {'experiment': 0.33, 'hour': 0.2, 'platform_os': 0.0, 'browser': 0.0, 'day_of_week': 0.24, 'brand': 0.22}
# Run params saved
# Run metrics saved
# logging figures
# figures saved with mlflow
# figures saved
# Saving artifacts
# saving dict
# Successfully registered model 'Chrome Mobile WebView Browser_XGBoost Classifier_Thu-Sep--1-09:57:11-2022'.
# 2022/09/01 09:57:19 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: Chrome Mobile WebView Browser_XGBoost Classifier_Thu-Sep--1-09:57:11-2022, version 1
# Created version '1' of model 'Chrome Mobile WebView Browser_XGBoost Classifier_Thu-Sep--1-09:57:11-2022'.
# Run - XGBoost Classifier is logged to Experiment - Chrome Mobile WebView Browser

# %% [markdown]
# ### Facebook Browser (v5 on dvc)

# %%
df = dvc_get_data(path='data/AdSmartABdata.csv', 
                version='v5', experiment_name="Facebook Browser")
df = df.drop(columns=['Unnamed: 0'])
df.info()
# Out:
# 2022/09/01 09:58:23 INFO mlflow.tracking.fluent: Experiment with name 'Facebook Browser' does not exist. Creating a new experiment.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   experiment   156 non-null    object
#  1   hour         156 non-null    int64
#  2   platform_os  156 non-null    int64
#  3   browser      156 non-null    object
#  4   day_of_week  156 non-null    object
#  5   brand        156 non-null    object
#  6   response     156 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 8.7+ KB

# %% [markdown]
# #### Logistic Regression on Browser Facebook

# %%
try:
    mlflow.end_run()
except:
    pass

# %%
X = df.drop(columns=['response'])
y = df['response'].values
model = LogisticRegression()
run_train_pipeline(model, X, y, 
                experiment_name='Facebook Browser',
                run_name='Logistic regression')

mlflow.end_run()
# Out:
# {'accuracy': 0.6, 'precision': 0.62, 'recall': 0.36, 'entropy': 0.67, 'true_pos': 20, 'true_neg': 8, 'false_pos': 5, 'false_neg': 14}
# {'experiment': -0.06, 'hour': -0.02, 'platform_os': 0.0, 'browser': 0.0, 'day_of_week': -0.14, 'brand': 0.25}
# Run params saved
# Run metrics saved
# logging figures
# figures saved with mlflow
# figures saved
# Saving artifacts
# saving dict
# Successfully registered model 'Facebook Browser_Logistic regression_Thu-Sep--1-09:59:55-2022'.
# 2022/09/01 10:00:07 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: Facebook Browser_Logistic regression_Thu-Sep--1-09:59:55-2022, version 1
# Created version '1' of model 'Facebook Browser_Logistic regression_Thu-Sep--1-09:59:55-2022'.
# Run - Logistic regression is logged to Experiment - Facebook Browser

# %% [markdown]
# #### RandomForestClassifier on Browser Facebook

# %%
model = RandomForestClassifier(max_depth=20)
run_train_pipeline(model, X, y, 
                experiment_name='Facebook Browser',
                run_name='depth 20 random forest')
mlflow.end_run()
# Out:
# {'accuracy': 0.45, 'precision': 0.3, 'recall': 0.14, 'entropy': 0.76, 'true_pos': 18, 'true_neg': 3, 'false_pos': 7, 'false_neg': 19}
# {'experiment': 0.06, 'hour': 0.6, 'platform_os': 0.0, 'browser': 0.0, 'day_of_week': 0.28, 'brand': 0.06}
# Run params saved
# Run metrics saved
# logging figures
# figures saved with mlflow
# figures saved
# Saving artifacts
# saving dict
# Successfully registered model 'Facebook Browser_depth 20 random forest_Thu-Sep--1-10:00:59-2022'.
# 2022/09/01 10:01:10 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: Facebook Browser_depth 20 random forest_Thu-Sep--1-10:00:59-2022, version 1
# Created version '1' of model 'Facebook Browser_depth 20 random forest_Thu-Sep--1-10:00:59-2022'.
# Run - depth 20 random forest is logged to Experiment - Facebook Browser

# %% [markdown]
# #### XGBoost on Browser Facebook

# %%
model = XGBClassifier()
run_train_pipeline(model, X, y, 
                experiment_name='Facebook Browser',
                run_name='XGBoost Classifier')
mlflow.end_run()
# Out:
# {'accuracy': 0.4, 'precision': 0.2, 'recall': 0.09, 'entropy': 1.02, 'true_pos': 17, 'true_neg': 2, 'false_pos': 8, 'false_neg': 20}
# {'experiment': 0.26, 'hour': 0.28, 'platform_os': 0.0, 'browser': 0.0, 'day_of_week': 0.33, 'brand': 0.13}
# Run params saved
# Run metrics saved
# logging figures
# figures saved with mlflow
# figures saved
# Saving artifacts
# saving dict
# Successfully registered model 'Facebook Browser_XGBoost Classifier_Thu-Sep--1-10:01:58-2022'.
# 2022/09/01 10:02:07 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: Facebook Browser_XGBoost Classifier_Thu-Sep--1-10:01:58-2022, version 1
# Created version '1' of model 'Facebook Browser_XGBoost Classifier_Thu-Sep--1-10:01:58-2022'.
# Run - XGBoost Classifier is logged to Experiment - Facebook Browser

# %% [markdown]
# ### Samsung Internet Browser (v6 on dvc)

# %%
df = dvc_get_data(path='data/AdSmartABdata.csv', 
                version='v6', experiment_name="Samsung Internet Browser")
df = df.drop(columns=['Unnamed: 0'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   experiment   145 non-null    object
#  1   hour         145 non-null    int64
#  2   platform_os  145 non-null    int64
#  3   browser      145 non-null    object
#  4   day_of_week  145 non-null    object
#  5   brand        145 non-null    object
#  6   response     145 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 8.1+ KB

# %%
df.head()
# Out:
#   experiment  hour  platform_os           browser day_of_week        brand  \
# 0    control    15            6  Samsung Internet      Friday  known brand
# 1    exposed    20            6  Samsung Internet    Thursday  known brand
# 2    exposed     3            6  Samsung Internet     Tuesday  known brand
# 3    exposed     0            6  Samsung Internet    Thursday  known brand
# 4    control    15            6  Samsung Internet      Friday  known brand
#
#    response
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %% [markdown]
# #### Logistic Regression on Samsung Internet Browser

# %%
try:
    mlflow.end_run()
except:
    pass

# %%
X = df.drop(columns=['response'])
y = df['response'].values
model = LogisticRegression()
run_train_pipeline(model, X, y, 
                experiment_name='Samsung Internet Browser',
                run_name='Logistic regression')

mlflow.end_run()
# Out:
# {'accuracy': 0.45, 'precision': 0.42, 'recall': 0.38, 'entropy': 0.85, 'true_pos': 12, 'true_neg': 8, 'false_pos': 11, 'false_neg': 13}
# {'experiment': -0.52, 'hour': 0.25, 'platform_os': 0.0, 'browser': 0.0, 'day_of_week': -0.19, 'brand': 0.0}
# Run params saved
# Run metrics saved
# logging figures
# figures saved with mlflow
# figures saved
# Saving artifacts
# saving dict
# Successfully registered model 'Samsung Internet Browser_Logistic regression_Thu-Sep--1-10:05:02-2022'.
# 2022/09/01 10:05:13 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: Samsung Internet Browser_Logistic regression_Thu-Sep--1-10:05:02-2022, version 1
# Created version '1' of model 'Samsung Internet Browser_Logistic regression_Thu-Sep--1-10:05:02-2022'.
# Run - Logistic regression is logged to Experiment - Samsung Internet Browser

# %% [markdown]
# #### RandomForestClassifier on Samsung Internet Browser

# %%
model = RandomForestClassifier(max_depth=20)
run_train_pipeline(model, X, y, 
                experiment_name='Samsung Internet Browser',
                run_name='depth 20 random forest')
mlflow.end_run()
# Out:
# {'accuracy': 0.41, 'precision': 0.39, 'recall': 0.43, 'entropy': 1.16, 'true_pos': 9, 'true_neg': 9, 'false_pos': 14, 'false_neg': 12}
# {'experiment': 0.13, 'hour': 0.56, 'platform_os': 0.0, 'browser': 0.0, 'day_of_week': 0.31, 'brand': 0.0}
# Run params saved
# Run metrics saved
# logging figures
# figures saved with mlflow
# figures saved
# Saving artifacts
# saving dict
# Successfully registered model 'Samsung Internet Browser_depth 20 random forest_Thu-Sep--1-10:06:04-2022'.
# 2022/09/01 10:06:19 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: Samsung Internet Browser_depth 20 random forest_Thu-Sep--1-10:06:04-2022, version 1
# Created version '1' of model 'Samsung Internet Browser_depth 20 random forest_Thu-Sep--1-10:06:04-2022'.
# Run - depth 20 random forest is logged to Experiment - Samsung Internet Browser

# %% [markdown]
# #### XGBoost on Samsung Internet Browser

# %%
model = XGBClassifier()
run_train_pipeline(model, X, y, 
                experiment_name='Samsung Internet Browser',
                run_name='XGBoost Classifier')
mlflow.end_run()
# Out:
# {'accuracy': 0.45, 'precision': 0.44, 'recall': 0.52, 'entropy': 1.3, 'true_pos': 9, 'true_neg': 11, 'false_pos': 14, 'false_neg': 10}
# {'experiment': 0.5, 'hour': 0.22, 'platform_os': 0.0, 'browser': 0.0, 'day_of_week': 0.27, 'brand': 0.0}
# Run params saved
# Run metrics saved
# logging figures
# figures saved with mlflow
# figures saved
# Saving artifacts
# saving dict
# Successfully registered model 'Samsung Internet Browser_XGBoost Classifier_Thu-Sep--1-10:07:19-2022'.
# 2022/09/01 10:07:34 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: Samsung Internet Browser_XGBoost Classifier_Thu-Sep--1-10:07:19-2022, version 1
# Created version '1' of model 'Samsung Internet Browser_XGBoost Classifier_Thu-Sep--1-10:07:19-2022'.
# Run - XGBoost Classifier is logged to Experiment - Samsung Internet Browser

# %% [markdown]
# ### Modeling for Versioned Data Based on Platform OS

# %% [markdown]
# ### Platform OS 6 (v8 on dvc)

# %%
df = dvc_get_data(path='data/AdSmartABdata.csv', 
                version='v3', experiment_name="Platform OS 6")
df = df.drop(columns=['Unnamed: 0'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 695 entries, 0 to 694
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   experiment   695 non-null    object
#  1   hour         695 non-null    int64
#  2   platform_os  695 non-null    int64
#  3   browser      695 non-null    object
#  4   day_of_week  695 non-null    object
#  5   brand        695 non-null    object
#  6   response     695 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 38.1+ KB

# %%
df.head()
# Out:
#   experiment  hour  platform_os        browser day_of_week    brand  response
# 0    exposed    16            6  Chrome Mobile    Saturday  generic         1
# 1    exposed     8            6  Chrome Mobile      Monday  generic         0
# 2    control    15            6  Chrome Mobile      Friday  generic         0
# 3    exposed     2            6  Chrome Mobile      Friday  generic         0
# 4    control    15            6  Chrome Mobile      Friday  generic         1

# %% [markdown]
# #### Logistic Regression on Platform OS 6

# %%
try:
    mlflow.end_run()
except:
    pass

# %%
X = df.drop(columns=['response'])
y = df['response'].values
model = LogisticRegression()
run_train_pipeline(model, X, y, 
                experiment_name='Platform OS 6',
                run_name='Logistic regression')

mlflow.end_run()
# Out:
# {'accuracy': 0.52, 'precision': 0.41, 'recall': 0.21, 'entropy': 0.7, 'true_pos': 90, 'true_neg': 19, 'false_pos': 27, 'false_neg': 73}
# {'experiment': -0.12, 'hour': 0.08, 'platform_os': 0.0, 'browser': 0.0, 'day_of_week': 0.14, 'brand': 0.21}
# Run params saved
# Run metrics saved
# logging figures
# figures saved with mlflow
# figures saved
# Saving artifacts
# saving dict
# Successfully registered model 'Platform OS 6_Logistic regression_Thu-Sep--1-10:25:42-2022'.
# 2022/09/01 10:26:04 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: Platform OS 6_Logistic regression_Thu-Sep--1-10:25:42-2022, version 1
# Created version '1' of model 'Platform OS 6_Logistic regression_Thu-Sep--1-10:25:42-2022'.
# Run - Logistic regression is logged to Experiment - Platform OS 6

# %% [markdown]
# #### RandomForestClassifier on Platform OS 6

# %%
model = RandomForestClassifier(max_depth=20)
run_train_pipeline(model, X, y, 
                experiment_name='PLatform OS 6',
                run_name='depth 20 random forest')
mlflow.end_run()
# Out:
# {'accuracy': 0.52, 'precision': 0.43, 'recall': 0.27, 'entropy': 1.06, 'true_pos': 84, 'true_neg': 25, 'false_pos': 33, 'false_neg': 67}
# {'experiment': 0.03, 'hour': 0.71, 'platform_os': 0.0, 'browser': 0.0, 'day_of_week': 0.22, 'brand': 0.03}
# 2022/09/01 10:27:19 INFO mlflow.tracking.fluent: Experiment with name 'PLatform OS 6' does not exist. Creating a new experiment.
# Run params saved
# Run metrics saved
# logging figures
# figures saved with mlflow
# figures saved
# Saving artifacts
# saving dict
# Successfully registered model 'PLatform OS 6_depth 20 random forest_Thu-Sep--1-10:27:28-2022'.
# 2022/09/01 10:27:37 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: PLatform OS 6_depth 20 random forest_Thu-Sep--1-10:27:28-2022, version 1
# Created version '1' of model 'PLatform OS 6_depth 20 random forest_Thu-Sep--1-10:27:28-2022'.
# ...

# %% [markdown]
# #### XGBoost on Platform OS 6

# %%
model = XGBClassifier()
run_train_pipeline(model, X, y, 
                experiment_name='Platform OS 6',
                run_name='XGBoost Classifier')
mlflow.end_run()
# Out:
# {'accuracy': 0.51, 'precision': 0.43, 'recall': 0.34, 'entropy': 0.85, 'true_pos': 76, 'true_neg': 31, 'false_pos': 41, 'false_neg': 61}
# {'experiment': 0.25, 'hour': 0.28, 'platform_os': 0.0, 'browser': 0.0, 'day_of_week': 0.24, 'brand': 0.22}
# Run params saved
# Run metrics saved
# logging figures
# figures saved with mlflow
# figures saved
# Saving artifacts
# saving dict
# Successfully registered model 'Platform OS 6_XGBoost Classifier_Thu-Sep--1-10:28:50-2022'.
# 2022/09/01 10:28:57 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: Platform OS 6_XGBoost Classifier_Thu-Sep--1-10:28:50-2022, version 1
# Created version '1' of model 'Platform OS 6_XGBoost Classifier_Thu-Sep--1-10:28:50-2022'.
# Run - XGBoost Classifier is logged to Experiment - Platform OS 6
